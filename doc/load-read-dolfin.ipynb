# %%
import pyvista as pv
from pyvista import examples

# %%
saved_file, _ = examples.downloads._download_file("dolfin_fine.xml")
print(saved_file)
# Out:
# /home/jovyan/.local/share/pyvista/examples/dolfin_fine.xml

# %%
dolfin = pv.read(saved_file)
dolfin
# Out:
# UnstructuredGrid (0x7fa6a6b975e0)
#   N Cells:	5400
#   N Points:	2868
#   X Bounds:	0.000e+00, 1.000e+00
#   Y Bounds:	0.000e+00, 1.000e+00
#   Z Bounds:	0.000e+00, 0.000e+00
#   N Arrays:	0

# %%
dolfin.plot(show_edges=True, cpos="xy")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FA81AF97940>
